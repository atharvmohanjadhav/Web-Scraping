# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
webpage = requests.get("https://www.nirfindia.org/Rankings/2024/EngineeringRanking.html")

# %%
webpage
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(webpage.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
# ...

# %%
e_id = []
for i in range(0,1100,11):
    e_id.append(soup.find_all("td")[i].text)

e_name = []
for i in range(1,1100,11):
    e_name.append(soup.find_all("td")[i].text.split("More")[0])

e_TLR = []
for i in range(2,1100,11):
    e_TLR.append(soup.find_all("td")[i].text)

e_RPC = []
for i in range(3,1100,11):
    e_RPC.append(soup.find_all("td")[i].text)


e_GO = []
for i in range(4,1100,11):
    e_GO.append(soup.find_all("td")[i].text)


e_OI = []
for i in range(5,1100,11):
    e_OI.append(soup.find_all("td")[i].text)


e_PERCEPTION = []
for i in range(6,1100,11):
    e_PERCEPTION.append(soup.find_all("td")[i].text)


e_city = []
for i in range(7,1100,11):
    e_city.append(soup.find_all("td")[i].text)


e_state = []
for i in range(8,1100,11):
    e_state.append(soup.find_all("td")[i].text)


e_score = []
for i in range(9,1100,11):
    e_score.append(soup.find_all("td")[i].text)


e_rank = []
for i in range(10,1100,11):
    e_rank.append(soup.find_all("td")[i].text)
    

field = []
for i in range(100):
    field.append("Engineering")

e_df = pd.DataFrame({"Institute Id":e_id,"Name":e_name, "TLR":e_TLR, "RPC":e_RPC,"GO":e_GO,
                   "OI":e_OI,
                   "Perception":e_PERCEPTION,
                   "City":e_city,
                   "State":e_state,
                   "Score":e_score,
                   "Rank":e_rank,"Field":field})

# %%
e_df.head()
# Out:
#   Institute Id                                      Name    TLR    RPC     GO  \
# 0  IR-E-U-0456     Indian Institute of Technology Madras  95.79  93.10  81.07
# 1  IR-E-I-1074      Indian Institute of Technology Delhi  85.71  92.20  84.52
# 2  IR-E-U-0306     Indian Institute of Technology Bombay  86.34  84.18  84.78
# 3  IR-E-I-1075     Indian Institute of Technology Kanpur  94.25  74.08  89.05
# 4  IR-E-U-0573  Indian Institute of Technology Kharagpur  78.22  79.28  79.16
#
#       OI Perception       City          State  Score Rank        Field
# 0  65.85     100.00    Chennai     Tamil Nadu  89.46    1  Engineering
# 1  65.39      98.53  New Delhi          Delhi  86.66    2  Engineering
# 2  58.67      91.13     Mumbai    Maharashtra  83.09    3  Engineering
# 3  60.62      84.19     Kanpur  Uttar Pradesh  82.79    4  Engineering
# 4  57.83      80.26  Kharagpur    West Bengal  76.88    5  Engineering

# %%
e_df.shape
# Out:
# (100, 12)

# %%
webpage1 = requests.get("https://www.nirfindia.org/Rankings/2024/MedicalRanking.html")
soup1 = BeautifulSoup(webpage1.content)

# %%
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
# ...

# %%
soup1.find_all("td")[1].text.split("More")[0]
# Out:
# 'All India Institute of Medical Sciences Delhi'

# %%
m_id = []
for i in range(0,550,11):
    m_id.append(soup1.find_all("td")[i].text)

m_name = []
for i in range(1,550,11):
    m_name.append(soup1.find_all("td")[i].text.split("More")[0])

m_TLR = []
for i in range(2,550,11):
    m_TLR.append(soup1.find_all("td")[i].text)

m_RPC = []
for i in range(3,550,11):
    m_RPC.append(soup1.find_all("td")[i].text)


m_GO = []
for i in range(4,550,11):
    m_GO.append(soup1.find_all("td")[i].text)


m_OI = []
for i in range(5,550,11):
    m_OI.append(soup1.find_all("td")[i].text)


m_PERCEPTION = []
for i in range(6,550,11):
    m_PERCEPTION.append(soup1.find_all("td")[i].text)


m_city = []
for i in range(7,550,11):
    m_city.append(soup1.find_all("td")[i].text)


m_state = []
for i in range(8,550,11):
    m_state.append(soup1.find_all("td")[i].text)


m_score = []
for i in range(9,550,11):
    m_score.append(soup1.find_all("td")[i].text)


m_rank = []
for i in range(10,550,11):
    m_rank.append(soup1.find_all("td")[i].text)
    

field1 = []
for i in range(50):
    field1.append("Medical")

m_df = pd.DataFrame({"Institute Id":m_id,"Name":m_name, "TLR":m_TLR, "RPC":m_RPC,"GO":m_GO,
                   "OI":m_OI,
                   "Perception":m_PERCEPTION,
                   "City":m_city,
                   "State":m_state,
                   "Score":m_score,
                   "Rank":m_rank,"Field":field1})

# %%
m_df.head()
# Out:
#    Institute Id                                               Name    TLR  \
# 0     IR-D-N-15      All India Institute of Medical Sciences Delhi  97.33
# 1   IR-D-U-0079  Post Graduate Institute of Medical Education a...  91.49
# 2  IR-D-C-45654                          Christian Medical College  95.64
# 3   IR-D-U-0236  National Institute of Mental Health and Neuro ...  88.30
# 4   IR-D-U-0368  Jawaharlal Institute of Post Graduate Medical ...  86.45
#
#      RPC     GO     OI Perception        City        State  Score Rank  \
# 0  94.82  98.44  71.29     100.00   New Delhi        Delhi  94.46    1
# 1  79.94  78.86  67.87      68.37  Chandigarh   Chandigarh  80.83    2
# 2  47.93  90.10  62.69      77.55     Vellore   Tamil Nadu  75.11    3
# 3  57.73  79.84  70.82      50.63   Bengaluru    Karnataka  71.92    4
# 4  44.84  89.87  67.81      66.00  Puducherry  Pondicherry  70.74    5
#
#      Field
# 0  Medical
# 1  Medical
# 2  Medical
# 3  Medical
# 4  Medical

# %%
m_df.shape
# Out:
# (50, 12)

# %%
webpage2 = requests.get("https://www.nirfindia.org/Rankings/2024/PharmacyRanking.html")
soup2 = BeautifulSoup(webpage2.content)

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
# ...

# %%
soup2.find_all("td")[1].text.split("More")[0]
# Out:
# 'Jamia Hamdard'

# %%
p_id = []
for i in range(0,1100,11):
    p_id.append(soup2.find_all("td")[i].text)

p_name = []
for i in range(1,1100,11):
    p_name.append(soup2.find_all("td")[i].text.split("More")[0])

p_TLR = []
for i in range(2,1100,11):
    p_TLR.append(soup2.find_all("td")[i].text)

p_RPC = []
for i in range(3,1100,11):
    p_RPC.append(soup2.find_all("td")[i].text)


p_GO = []
for i in range(4,1100,11):
    p_GO.append(soup2.find_all("td")[i].text)


p_OI = []
for i in range(5,1100,11):
    p_OI.append(soup2.find_all("td")[i].text)


p_PERCEPTION = []
for i in range(6,1100,11):
    p_PERCEPTION.append(soup2.find_all("td")[i].text)


p_city = []
for i in range(7,1100,11):
    p_city.append(soup2.find_all("td")[i].text)


p_state = []
for i in range(8,1100,11):
    p_state.append(soup2.find_all("td")[i].text)


p_score = []
for i in range(9,1100,11):
    p_score.append(soup2.find_all("td")[i].text)


p_rank = []
for i in range(10,1100,11):
    p_rank.append(soup2.find_all("td")[i].text)
    

field2 = []
for i in range(100):
    field2.append("Pharmacy")

p_df = pd.DataFrame({"Institute Id":p_id,"Name":p_name, "TLR":p_TLR, "RPC":p_RPC,"GO":p_GO,
                   "OI":p_OI,
                   "Perception":p_PERCEPTION,
                   "City":p_city,
                   "State":p_state,
                   "Score":p_score,
                   "Rank":p_rank,"Field":field2})

# %%
p_df.head()
# Out:
#    Institute Id                                               Name    TLR  \
# 0   IR-P-U-0107                                      Jamia Hamdard  80.01
# 1   IR-P-I-1077  National Institute of Pharmaceutical Education...  92.05
# 2   IR-P-U-0391  Birla Institute of Technology and Science, Pilani  89.45
# 3  IR-P-C-35006                            JSS College of Pharmacy  85.88
# 4   IR-P-U-0308                   Institute of Chemical Technology  80.23
#
#      RPC     GO     OI Perception       City        State  Score Rank  \
# 0  85.34  86.50  71.11     100.00  New Delhi        Delhi  84.01    1
# 1  63.33  94.60  71.76      75.85  Hyderabad    Telangana  80.29    2
# 2  72.95  85.63  70.39      60.62     Pilani    Rajasthan  78.95    3
# 3  51.70  93.10  84.64      87.82       Ooty   Tamil Nadu  77.13    4
# 4  69.45  89.34  56.18      62.95     Mumbai  Maharashtra  74.69    5
#
#       Field
# 0  Pharmacy
# 1  Pharmacy
# 2  Pharmacy
# 3  Pharmacy
# 4  Pharmacy

# %%
p_df.shape
# Out:
# (100, 12)

# %%
webpage3 = requests.get("https://www.nirfindia.org/Rankings/2024/LawRanking.html")
soup3 = BeautifulSoup(webpage3.content)
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
# ...

# %%
soup3.find_all("td")[1].text.split("More")[0]
# Out:
# 'National Law School of India University'

# %%
l_id = []
for i in range(0,440,11):
    l_id.append(soup3.find_all("td")[i].text)

l_name = []
for i in range(1,440,11):
    l_name.append(soup3.find_all("td")[i].text.split("More")[0])

l_TLR = []
for i in range(2,440,11):
    l_TLR.append(soup3.find_all("td")[i].text)

l_RPC = []
for i in range(3,440,11):
    l_RPC.append(soup3.find_all("td")[i].text)


l_GO = []
for i in range(4,440,11):
    l_GO.append(soup3.find_all("td")[i].text)


l_OI = []
for i in range(5,440,11):
    l_OI.append(soup3.find_all("td")[i].text)


l_PERCEPTION = []
for i in range(6,440,11):
    l_PERCEPTION.append(soup3.find_all("td")[i].text)


l_city = []
for i in range(7,440,11):
    l_city.append(soup3.find_all("td")[i].text)


l_state = []
for i in range(8,440,11):
    l_state.append(soup3.find_all("td")[i].text)


l_score = []
for i in range(9,440,11):
    l_score.append(soup3.find_all("td")[i].text)


l_rank = []
for i in range(10,440,11):
    l_rank.append(soup3.find_all("td")[i].text)
    

field3 = []
for i in range(40):
    field3.append("Law")

l_df = pd.DataFrame({"Institute Id":l_id,"Name":l_name, "TLR":l_TLR, "RPC":l_RPC,"GO":l_GO,
                   "OI":l_OI,
                   "Perception":l_PERCEPTION,
                   "City":l_city,
                   "State":l_state,
                   "Score":l_score,
                   "Rank":l_rank,"Field":field3})

# %%
l_df.head()
# Out:
#    Institute Id                                               Name    TLR  \
# 0   IR-L-U-0238            National Law School of India University  90.31
# 1   IR-L-U-0111                            National Law University  87.17
# 2     IR-L-N-18                           Nalsar University of Law  88.21
# 3   IR-L-U-0585  The West Bengal National University of Juridic...  86.34
# 4  IR-L-C-19328                               Symbiosis Law School  84.91
#
#      RPC     GO     OI Perception       City        State  Score Rank Field
# 0  61.85  85.40  70.80     100.00  Bengaluru    Karnataka  83.83    1   Law
# 1  37.03  82.44  71.29      93.20  New Delhi        Delhi  77.48    2   Law
# 2  37.04  86.76  71.76      73.40  Hyderabad    Telangana  77.05    3   Law
# 3  49.44  83.24  69.23      66.99    Kolkata  West Bengal  76.39    4   Law
# 4  19.69  94.23  75.09      66.36       Pune  Maharashtra  74.62    5   Law

# %%
l_df.shape
# Out:
# (40, 12)

# %%
webpage4 = requests.get("https://www.nirfindia.org/Rankings/2024/ManagementRanking.html")
soup4 = BeautifulSoup(webpage4.content)
print(soup4.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
# ...

# %%
soup4.find_all("td")[1].text.split("More")[0]
# Out:
# 'Indian Institute of Management Ahmedabad'

# %%
mn_id = []
for i in range(0,1100,11):
    mn_id.append(soup4.find_all("td")[i].text)

mn_name = []
for i in range(1,1100,11):
    mn_name.append(soup4.find_all("td")[i].text.split("More")[0])

mn_TLR = []
for i in range(2,1100,11):
    mn_TLR.append(soup4.find_all("td")[i].text)

mn_RPC = []
for i in range(3,1100,11):
    mn_RPC.append(soup4.find_all("td")[i].text)


mn_GO = []
for i in range(4,1100,11):
    mn_GO.append(soup4.find_all("td")[i].text)


mn_OI = []
for i in range(5,1100,11):
    mn_OI.append(soup4.find_all("td")[i].text)


mn_PERCEPTION = []
for i in range(6,1100,11):
    mn_PERCEPTION.append(soup4.find_all("td")[i].text)


mn_city = []
for i in range(7,1100,11):
    mn_city.append(soup4.find_all("td")[i].text)


mn_state = []
for i in range(8,1100,11):
    mn_state.append(soup4.find_all("td")[i].text)


mn_score = []
for i in range(9,1100,11):
    mn_score.append(soup4.find_all("td")[i].text)


mn_rank = []
for i in range(10,1100,11):
    mn_rank.append(soup4.find_all("td")[i].text)
    

field4 = []
for i in range(100):
    field4.append("Management")

mn_df = pd.DataFrame({"Institute Id":mn_id,"Name":mn_name, "TLR":mn_TLR, "RPC":mn_RPC,"GO":mn_GO,
                   "OI":mn_OI,
                   "Perception":mn_PERCEPTION,
                   "City":mn_city,
                   "State":mn_state,
                   "Score":mn_score,
                   "Rank":mn_rank,"Field":field4})

# %%
mn_df.head()
# Out:
#   Institute Id                                      Name    TLR    RPC     GO  \
# 0  IR-M-S-8890  Indian Institute of Management Ahmedabad  91.88  63.89  98.71
# 1  IR-M-S-8903  Indian Institute of Management Bangalore  90.08  56.71  98.41
# 2  IR-M-S-8909  Indian Institute of Management Kozhikode  86.99  58.96  94.37
# 3  IR-M-I-1074      Indian Institute of Technology Delhi  72.21  78.39  89.51
# 4  IR-M-S-8972   Indian Institute of Management Calcutta  84.12  48.09  99.09
#
#       OI Perception       City        State  Score Rank       Field
# 0  71.72      96.81  Ahmedabad      Gujarat  83.32    1  Management
# 1  74.54     100.00  Bengaluru    Karnataka  81.16    2  Management
# 2  77.10      75.30  Kozhikode       Kerala  77.90    3  Management
# 3  67.37      64.25  New Delhi        Delhi  76.25    4  Management
# 4  70.46      85.29    Kolkata  West Bengal  75.07    5  Management

# %%
mn_df.shape
# Out:
# (100, 12)

# %%
webpage5 = requests.get("https://www.nirfindia.org/Rankings/2024/ArchitectureRanking.html")
soup5 = BeautifulSoup(webpage5.content)
print(soup5.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
# ...

# %%
soup5.find_all("td")[1].text.split("More")[0]
# Out:
# 'Indian Institute of Technology Roorkee'

# %%
ap_id = []
for i in range(0,440,11):
    ap_id.append(soup5.find_all("td")[i].text)

ap_name = []
for i in range(1,440,11):
    ap_name.append(soup5.find_all("td")[i].text.split("More")[0])

ap_TLR = []
for i in range(2,440,11):
    ap_TLR.append(soup5.find_all("td")[i].text)

ap_RPC = []
for i in range(3,440,11):
    ap_RPC.append(soup5.find_all("td")[i].text)


ap_GO = []
for i in range(4,440,11):
    ap_GO.append(soup5.find_all("td")[i].text)


ap_OI = []
for i in range(5,440,11):
    ap_OI.append(soup5.find_all("td")[i].text)


ap_PERCEPTION = []
for i in range(6,440,11):
    ap_PERCEPTION.append(soup5.find_all("td")[i].text)


ap_city = []
for i in range(7,440,11):
    ap_city.append(soup5.find_all("td")[i].text)


ap_state = []
for i in range(8,440,11):
    ap_state.append(soup5.find_all("td")[i].text)


ap_score = []
for i in range(9,440,11):
    ap_score.append(soup5.find_all("td")[i].text)


ap_rank = []
for i in range(10,440,11):
    ap_rank.append(soup5.find_all("td")[i].text)
    

field5 = []
for i in range(40):
    field5.append("Architecture and Planning")

ap_df = pd.DataFrame({"Institute Id":ap_id,"Name":ap_name, "TLR":ap_TLR, "RPC":ap_RPC,"GO":ap_GO,
                   "OI":ap_OI,
                   "Perception":ap_PERCEPTION,
                   "City":ap_city,
                   "State":ap_state,
                   "Score":ap_score,
                   "Rank":ap_rank,"Field":field5})

# %%
ap_df.head()
# Out:
#   Institute Id                                               Name    TLR  \
# 0  IR-A-U-0560             Indian Institute of Technology Roorkee  81.72
# 1  IR-A-U-0573           Indian Institute of Technology Kharagpur  76.48
# 2  IR-A-U-0263           National Institute of Technology Calicut  93.63
# 3  IR-A-U-0584  Indian Institute of Engineering Science and Te...  76.13
# 4  IR-A-U-0116      School of Planning and Architecture New Delhi  78.60
#
#      RPC     GO     OI Perception       City        State  Score Rank  \
# 0  93.02  93.38  74.46      75.00    Roorkee  Uttarakhand  84.92    1
# 1  84.65  90.85  67.60      82.56  Kharagpur  West Bengal  80.71    2
# 2  59.49  81.67  71.86      66.45  Kozhikode       Kerala  79.51    3
# 3  56.74  73.60  69.03      62.91     Howrah  West Bengal  69.71    4
# 4  29.07  70.28  76.93     100.00  New Delhi        Delhi  69.00    5
#
#                        Field
# 0  Architecture and Planning
# 1  Architecture and Planning
# ...

# %%
ap_df.shape
# Out:
# (40, 12)

# %%
webpage6 = requests.get("https://www.nirfindia.org/Rankings/2024/AgricultureRanking.html")
soup6 = BeautifulSoup(webpage6.content)
print(soup6.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    (function (i, s, o, g, r, a, m) {i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {(i[r].q = i[r].q || []).push(arguments)}, i[r].l = 1 * new Date(); a = s.createElement(o),m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');ga('create', 'UA-75867016-1', 'auto');ga('send', 'pageview');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    MoE, National Institute Ranking Framework (NIRF)
#   </title>
#   <link href="https://www.nirfindia.org/css/style.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.nirfindia.org/js/modernizr.js" type="text/javascript">
#   </script>
#   <script src="https://www.nirfindia.org/js/jquery-min.js" type="text/javascript">
# ...

# %%
soup6.find_all("td")[1].text.split("More")[0]
# Out:
# 'Indian Agricultural Research Institute'

# %%
a_id = []
for i in range(0,440,11):
    a_id.append(soup6.find_all("td")[i].text)

a_name = []
for i in range(1,440,11):
    a_name.append(soup6.find_all("td")[i].text.split("More")[0])

a_TLR = []
for i in range(2,440,11):
    a_TLR.append(soup6.find_all("td")[i].text)

a_RPC = []
for i in range(3,440,11):
    a_RPC.append(soup6.find_all("td")[i].text)


a_GO = []
for i in range(4,440,11):
    a_GO.append(soup6.find_all("td")[i].text)


a_OI = []
for i in range(5,440,11):
    a_OI.append(soup6.find_all("td")[i].text)


a_PERCEPTION = []
for i in range(6,440,11):
    a_PERCEPTION.append(soup6.find_all("td")[i].text)


a_city = []
for i in range(7,440,11):
    a_city.append(soup6.find_all("td")[i].text)


a_state = []
for i in range(8,440,11):
    a_state.append(soup6.find_all("td")[i].text)


a_score = []
for i in range(9,440,11):
    a_score.append(soup6.find_all("td")[i].text)


a_rank = []
for i in range(10,440,11):
    a_rank.append(soup6.find_all("td")[i].text)
    

field6 = []
for i in range(40):
    field6.append("Agriculture and Allied Sectors")

a_df = pd.DataFrame({"Institute Id":a_id,"Name":a_name, "TLR":a_TLR, "RPC":a_RPC,"GO":a_GO,
                   "OI":a_OI,
                   "Perception":a_PERCEPTION,
                   "City":a_city,
                   "State":a_state,
                   "Score":a_score,
                   "Rank":a_rank,"Field":field6})

# %%
a_df.head()
# Out:
#   Institute Id                                             Name    TLR    RPC  \
# 0  IR-G-U-0101           Indian Agricultural Research Institute  89.80  92.79
# 1  IR-G-U-0171         ICAR - National Dairy Research Institute  78.54  60.44
# 2  IR-G-U-0381                   Punjab Agricultural University  87.98  67.49
# 3  IR-G-U-0500                         Banaras Hindu University  67.94  74.30
# 4  IR-G-U-0518  Indian Veterinary Research Institute, Izatnagar  87.23  54.71
#
#       GO     OI Perception       City          State  Score Rank  \
# 0  82.81  73.74      92.71  New Delhi          Delhi  87.98    1
# 1  87.07  62.65      58.08     Karnal        Haryana  71.18    2
# 2  51.84  49.96      76.16   Ludhiana         Punjab  69.63    3
# 3  71.04  58.96      55.38   Varanasi  Uttar Pradesh  68.32    4
# 4  77.21  56.30      41.12   Bareilly  Uttar Pradesh  67.76    5
#
#                             Field
# 0  Agriculture and Allied Sectors
# 1  Agriculture and Allied Sectors
# ...

# %%
a_df.shape
# Out:
# (40, 12)

# %%
final_df = pd.concat([e_df,m_df,mn_df,l_df,ap_df,p_df,a_df],ignore_index=True)

# %%
final_df.sample(10)
# Out:
#      Institute Id                                               Name    TLR  \
# 307  IR-A-C-43708                 College of Engineering, Trivandrum  56.16
# 429  IR-P-C-30768  College of Pharmacy, Pandit Bhagwat Dayal Shar...  59.94
# 455   IR-G-U-0004          Acharya N G Ranga Agricultural University  80.65
# 66   IR-E-C-37013                          PSG College of Technology  68.19
# 143  IR-D-C-16424                                    Medical College  68.19
# 221    IR-M-S-419          Jaipuria Institute of Management, Lucknow  71.51
# 367   IR-P-I-1280                       Maharshi Dayanand University  58.73
# 242    IR-M-S-164                           Rajagiri Business School  65.55
# 141  IR-D-C-48124     Government Medical College, Thiruvananthapuram  72.49
# 340   IR-P-U-0473         S.R.M. Institute of Science and Technology  78.30
#
#        RPC     GO     OI Perception                City           State  \
# ...

# %%
final_df.head()
# Out:
#   Institute Id                                      Name    TLR    RPC     GO  \
# 0  IR-E-U-0456     Indian Institute of Technology Madras  95.79  93.10  81.07
# 1  IR-E-I-1074      Indian Institute of Technology Delhi  85.71  92.20  84.52
# 2  IR-E-U-0306     Indian Institute of Technology Bombay  86.34  84.18  84.78
# 3  IR-E-I-1075     Indian Institute of Technology Kanpur  94.25  74.08  89.05
# 4  IR-E-U-0573  Indian Institute of Technology Kharagpur  78.22  79.28  79.16
#
#       OI Perception       City          State  Score Rank        Field
# 0  65.85     100.00    Chennai     Tamil Nadu  89.46    1  Engineering
# 1  65.39      98.53  New Delhi          Delhi  86.66    2  Engineering
# 2  58.67      91.13     Mumbai    Maharashtra  83.09    3  Engineering
# 3  60.62      84.19     Kanpur  Uttar Pradesh  82.79    4  Engineering
# 4  57.83      80.26  Kharagpur    West Bengal  76.88    5  Engineering

# %%
final_df.to_csv("NIRF Ranking 2024.csv")
